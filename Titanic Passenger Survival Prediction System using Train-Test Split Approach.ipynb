# %% [markdown]
# <br><br><br>
# <center> <h3 style="color:blue">========================================================</h3> </center>
# <center> <h3 style="color:green">In the Name of Allah, the Most Beneficent, the Most Merciful</h3> </center>
# <center> <h3 style="color:blue">========================================================</h3> </center>
# <br><br><br>

# %% [markdown]
#         *----------------------------- AUTHOR_DETAILS -------------------------------*
#         |                                                                            |
#         |        Project Title  = Titanic Passenger Survival Prediction System       |
#         |                                                                            |
#         |        Author         =  Dr. Muhammad Awais Qureshi
#         |                                                                            |
#         |        License        = Public Domain                                      |
#         |                                                                            |
#         |        Version        = 1.0                                                |
#         |                                                                            |
#         *----------------------------------------------------------------------------*

# %% [markdown]
# <br><br><br>
# <center> <h2 style="color:green">-------------------- PROJECT PURPOSE --------------------</h2> </center>
# <br>
# <center><h3>
# The main purpose of this Project is to demonstrate how the Titanic Passenger Survival Problem can be treated as a Supervised Machine Learning Problem using Python and Scikit-learn Machine Learning Toolkit </h3>
# <br>
# <center><h3> For this Purpose, In Sha Allah, we will execute the Machine Learning Cycle </h3>
# <br>
# <center> <h2 style="color:green">-------------------------------------------------------------------------</h2> </center>
# <br><br><br>

# %% [markdown]
# <h1 style="color:red">Titanic Passenger Survival Prediction System – Machine Learning Cycle</h1>

# %% [markdown]
# # Machine Learning Cycle
#
# ### Four phases of a Machine Learning Cycle are
#
# ### Training Phase
#
#     Build the Model using Training Data
#
# ### Testing Phase
#
#      Evaluate the performance of Model using Testing Data
#
# ### Application Phase
#
#      Deploy the Model in the Real-world, to predict Real-time unseen Data
#
# ### Feedback Phase
#
#     Take Feedback from the Users and Domain Experts to improve the Model

# %% [markdown]
# <h1 style="color:red">Executing Machine Learning Cycle Using a Single File</h1>

# %% [markdown]
# ### In Sha Allah, we will follow the following steps to execute the Machine Learning Cycle Using a Single File
#
# #### Step 1: Import Libraries
#
# #### Step 2: Load Sample Data
#
# #### Step 3: Understand and Pre-process Sample Data
#
#     Step 3.1: Understand Sample Data
#
#     Step 3.2: Pre-process Sample Data
#
# #### Step 4: Feature Extraction
#
# #### Step 5: Label Encoding (Input and Output is converted in Numeric Representation)
#
#     Step 5.1: Train the Label Encoder
#
#     Step 5.2: Label Encode the Output
#
#     Step 5.3: Label Encode the Input
#
# #### Step 6: Execute the Training Phase
#
#     Step 6.1: Splitting Sample Data into Training Data and Testing Data
#
#     Step 6.2: Splitting Input Vectors and Outputs / Labels of Training Data
#
#     Step 6.3: Train the Support Vector Classifier
#
#     Step 6.4: Save the Trained Model
#
# #### Step 7: Execute the Testing Phase
#
#     Step 7.1: Splitting Input Vectors and Outputs/Labels of Testing Data
#
#     Step 7.2: Load the Saved Model
#
#     Step 7.3: Evaluate the Performance of Trained Model
#
#         Step 7.3.1: Make Predictions with the Trained Model on Testing Data
#
#     Step 7.4: Calculate the Accuracy Score
#
# #### Step 8: Execute the Application Phase
#
#     Step 8.1: Take Input from User
#
#     Step 8.2: Convert User Input into Feature Vector (Exactly Same as Feature Vectors of Sample Data)
#
#     Step 8.3: Label Encoding of Feature Vector (Exactly Same as Label Encoded Feature Vectors of Sample Data)
#
#     Step 8.4: Load the Saved Model
#
#     Step 8.5: Model Prediction
#
#          Step 8.5.1: Apply Model on the Label Encoded Feature Vector of unseen instance and return Prediction to the User
#
# #### Step 9: Execute the Feedback Phase
#
# #### Step 10: Improve the Model based on Feedback

# %% [markdown]
# # Step 1: Import Libraries

# %%
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install prettytable
# !pip install astropy
# Out:
# Requirement already satisfied: numpy in c:\users\awais qureshi\anaconda3\lib\site-packages (2.1.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\awais qureshi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\awais qureshi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\awais qureshi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\awais qureshi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\awais qureshi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\awais qureshi\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\awais qureshi\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting prettytable
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: wcwidth in c:\users\awais qureshi\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.17.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: astropy in c:\users\awais qureshi\anaconda3\lib\site-packages (7.0.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\awais qureshi\anaconda3\lib\site-packages (from astropy) (2.1.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\awais qureshi\anaconda3\lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in c:\users\awais qureshi\anaconda3\lib\site-packages (from astropy) (0.2025.1.13.0.34.51)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from astropy) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\awais qureshi\anaconda3\lib\site-packages (from astropy) (24.2)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import Libraries

import numpy as np
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from sklearn.metrics import accuracy_score

from prettytable import PrettyTable   
from astropy.table import Table, Column

# %% [markdown]
# # Step 2: Load Sample Data

# %%
# Load Sample Data

''' 
*---------------------- LOAD_SAMPLE_DATA ------------------------*
|     Function: read_csv()                                       |
|             Purpose: Read a dataset in CSV file format         |
|     Arguments:                                                 |
|             path: Path to dataset file                         |
|             dataset: Dataset file name                         |
|     Return:                                                    |
|             dataset: Dataset in DataFrame format               |
*----------------------------------------------------------------*
'''
 
sample_data = pd.read_csv("sample-data.csv")

print("\n\nSample Data:")
print("============\n")
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data)
# Out:
# Sample Data:
# ============
#
#     PClass  Gender Sibling     Embarked Survived
# 0    Third    Male     One  Southampton       No
# 1   Second  Female    Zero  Southampton      Yes
# 2    Third    Male    Zero  Southampton       No
# 3    Third  Female   Three  Southampton      Yes
# 4    Third    Male    Zero   Queenstown       No
# 5    First  Female   Three  Southampton      Yes
# 6    Third    Male    Zero  Southampton       No
# 7    Third    Male    Zero  Southampton      Yes
# 8    First    Male    Zero  Southampton       No
# 9   Second    Male    Zero  Southampton      Yes
# 10   Third    Male     One   Queenstown       No
# 11   First    Male    Zero    Cherbourg      Yes
# 12   First    Male    Zero    Cherbourg       No
# 13  Second  Female    Zero  Southampton      Yes
# 14  Second    Male    Zero  Southampton       No
# 15   Third    Male     One    Cherbourg      Yes
# 16   Third    Male     Two    Cherbourg       No
# 17   Third    Male    Zero  Southampton      Yes
# 18   Third    Male    Zero  Southampton       No
# 19   Third  Female     One    Cherbourg      Yes
# 20   Third    Male    Zero    Cherbourg       No
# 21   First  Female    Zero  Southampton      Yes
# 22   First    Male    Zero    Cherbourg       No
# 23  Second  Female    Zero  Southampton      Yes
# 24   Third  Female     One  Southampton       No
# 25   Third  Female    Zero  Southampton      Yes
# 26   Third    Male    Zero  Southampton       No
# 27   Third    Male    Zero  Southampton      Yes
# 28   Third    Male    Zero  Southampton       No
# 29   Third  Female     One   Queenstown      Yes
# 30   Third  Female     Two  Southampton       No
# 31   First  Female    Zero    Cherbourg      Yes
# 32   Third    Male     Two  Southampton       No
# 33   First  Female    Zero  Southampton      Yes
# 34   First    Male     One    Cherbourg       No
# 35   First  Female    Zero  Southampton      Yes
# 36   First    Male     One  Southampton       No
# 37   Third  Female     One   Queenstown      Yes
# 38   Third  Female     One  Southampton       No
# 39  Second  Female     One  Southampton      Yes
# 40  Second  Female     One  Southampton       No
# 41   Third  Female    Zero   Queenstown      Yes
# 42   Third    Male    Zero    Cherbourg       No
# 43   First  Female    Zero    Cherbourg      Yes
# 44   Third    Male   Three  Southampton       No
# 45   Third  Female     One  Southampton      Yes
# 46   Third    Male    Zero  Southampton       No
# 47   Third    Male    Zero  Southampton      Yes
# 48   Third    Male     One  Southampton       No
# 49  Second  Female    Zero  Southampton      Yes
# 50   First    Male   Three  Southampton       No
# 51   Third    Male    Zero  Southampton      Yes
# 52   Third  Female     One  Southampton       No
# 53  Second  Female    Zero  Southampton      Yes
# 54   Third  Female   Three  Southampton       No
# 55   Third  Female    Zero  Southampton      Yes
# 56   Third  Female    Zero  Southampton       No
# 57   Third  Female     One  Southampton      Yes
# 58   Third    Male    Zero    Cherbourg       No
# 59   Third    Male    Zero  Southampton      Yes
# 60  Second    Male    Zero  Southampton       No
# 61   First  Female     One  Southampton      Yes
# 62   Third    Male   Three   Queenstown       No
# 63   Third  Female    Zero   Queenstown      Yes
# 64  Second  Female    Zero  Southampton       No
# 65   Third  Female    Zero    Cherbourg      Yes
# 66   Third    Male    Zero  Southampton       No
# 67  Second    Male    Zero  Southampton      Yes
# 68   Third    Male    Zero  Southampton       No
# 69   First    Male    Zero  Southampton      Yes
# 70   Third    Male    Zero  Southampton       No
# 71  Second    Male     Two  Southampton      Yes
# 72   Third    Male    Zero    Cherbourg       No
# 73   Third  Female    Zero  Southampton      Yes
# 74   Third  Female    Zero  Southampton       No
# 75   First  Female     One  Southampton      Yes
# 76   Third    Male     One  Southampton       No
# 77  Second  Female    Zero  Southampton      Yes
# 78   Third    Male    Zero  Southampton       No
# 79   Third  Female     Two  Southampton      Yes
# 80   Third    Male     Two  Southampton       No
# 81   Third  Female    Zero  Southampton      Yes
# 82   Third    Male    Zero  Southampton       No
# 83   First    Male     One  Southampton      Yes
# 84  Second    Male    Zero  Southampton       No
# 85   Third  Female     One   Queenstown      Yes
# 86  Second    Male    Zero  Southampton       No
# 87   First  Female     One  Southampton      Yes
# 88   Third    Male    Zero  Southampton       No
# 89  Second  Female    Zero  Southampton      Yes
# 90  Second    Male    Zero  Southampton       No
# 91  Second  Female    Zero  Southampton      Yes
# 92   Third    Male    Zero    Cherbourg       No
# 93   First    Male     One  Southampton      Yes
# 94   First    Male     One  Southampton       No
# 95   Third    Male     One    Cherbourg      Yes
# 96   Third    Male     One   Queenstown       No
# 97   Third    Male     One  Southampton      Yes
# 98  Second    Male     One  Southampton       No
# 99   Third    Male     One  Southampton      Yes

# %% [markdown]
# # Step 3: Understand and Pre-process Sample Data

# %% [markdown]
# ## Step 3.1: Understand Sample Data

# %%
# Understand Sample Data

print("\n\nAttributes in Sample Data:")
print("==========================\n")

print(sample_data.columns)

print("\n\nNumber of Instances in Sample Data:",sample_data["PClass"].count())
print("========================================\n")
# Out:
# Attributes in Sample Data:
# ==========================
#
# Index(['PClass', 'Gender', 'Sibling', 'Embarked', 'Survived'], dtype='object')
#
#
# Number of Instances in Sample Data: 100
# ========================================

# %% [markdown]
# ## Step 3.2: Pre-process Sample Data
#     o	Sample Data is already Preprocessed
#     o	No Preprocessing needs to be Performed

# %% [markdown]
# # Step 4: Feature Extraction
#     o	Features are already Extracted
#     o	No Feature Extraction needs to be Performed

# %% [markdown]
# # Step 5: Label Encoding the Sample Data (Input and Output is converted in Numeric Representation)

# %% [markdown]
# ## Step 5.1: Train the Label Encoder

# %%
# Train the Label Encoder

''' 
*------------------ TRAIN_LABEL_ENCODER --------------------*
|        Function: Fit()                                    |
|              Purpose: Fit or Train the Label Encoder      |
|        Arguments:                                         |
|               Labels: Target Values                       |
|        Return:                                            |
|               Instance: Returns an instance of self       |
*-----------------------------------------------------------*
''' 

# Labels

pclass = pd.DataFrame({"Pclass":["First","Second","Third"]})
gender = pd.DataFrame({"Gender":["Male","Female"]})
sibling = pd.DataFrame({"Sibling":["Zero","One","Two","Three"]})
embarked = pd.DataFrame({"Embarked":["Southampton","Cherbourg","Queenstown"]})
survived = pd.DataFrame({"Survived":["Yes","No"]})

# Initialize the Label Encoders 

pclass_label_encoder = LabelEncoder()
gender_label_encoder = LabelEncoder()
sibling_label_encoder = LabelEncoder()
embarked_label_encoder = LabelEncoder()
survived_label_encoder = LabelEncoder()

# Train the Label Encoders

pclass_label_encoder.fit(np.ravel(pclass))
gender_label_encoder.fit(np.ravel(gender))
sibling_label_encoder.fit(np.ravel(sibling))
embarked_label_encoder.fit(np.ravel(embarked))
survived_label_encoder.fit(np.ravel(survived))

import pickle

# Save trained label encoders
with open("pclass_encoder.pkl", "wb") as f:
    pickle.dump(pclass_label_encoder, f)

with open("gender_encoder.pkl", "wb") as f:
    pickle.dump(gender_label_encoder, f)

with open("sibling_encoder.pkl", "wb") as f:
    pickle.dump(sibling_label_encoder, f)

with open("embarked_encoder.pkl", "wb") as f:
    pickle.dump(embarked_label_encoder, f)

with open("survived_encoder.pkl", "wb") as f:
    pickle.dump(survived_label_encoder, f)

# %% [markdown]
# ## Step 5.2: Label Encode the Output

# %%
# Label Encoding of the Output

''' 
*------------------ LABEL_ENCODE_OUTPUT --------------------*
|        Function: Transform()                              |
|              Purpose: Transform Input (Categorical)       |
|                       into Numerical Representation       |
|        Arguments:                                         |
|              Attribute: Target values                     |
|        Return:                                            |
|              Attribute: Numerical Representation          |
*-----------------------------------------------------------*
'''

sample_data_encoded_output = sample_data.copy()
original_sample_data = sample_data.copy()

# Transform Output of into Numerical Representation

print("\n\nSurvived Attribute After Label Encoding:")
print("========================================\n")
sample_data["encoded_survived"] = survived_label_encoder.transform(sample_data['Survived'])
print(sample_data[["Survived", "encoded_survived"]])

# Print Original and Encoded Ouput Sample Data

sample_data_encoded_output[['PClass', 'Gender', 'Sibling', 'Embarked', 'Survived']] = sample_data[['PClass', 'Gender', 'Sibling', 'Embarked', 'encoded_survived']]
pd.set_option("display.max_rows", None, "display.max_columns", None)
print("\n\nOriginal Sample Data:")
print("=====================\n")
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(original_sample_data)
print("\n\nSample Data after Label Encoding of Output:")
print("===========================================\n")
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded_output)

# Save the Transformed Features into CSV File 

sample_data_encoded_output.to_csv(r'sample-data-encoded-output.csv', index = False, header = True)
# Out:
# Survived Attribute After Label Encoding:
# ========================================
#
#    Survived  encoded_survived
# 0        No                 0
# 1       Yes                 1
# 2        No                 0
# 3       Yes                 1
# 4        No                 0
# 5       Yes                 1
# 6        No                 0
# 7       Yes                 1
# 8        No                 0
# 9       Yes                 1
# 10       No                 0
# 11      Yes                 1
# 12       No                 0
# 13      Yes                 1
# 14       No                 0
# 15      Yes                 1
# 16       No                 0
# 17      Yes                 1
# 18       No                 0
# 19      Yes                 1
# 20       No                 0
# 21      Yes                 1
# 22       No                 0
# 23      Yes                 1
# 24       No                 0
# 25      Yes                 1
# 26       No                 0
# 27      Yes                 1
# 28       No                 0
# 29      Yes                 1
# 30       No                 0
# 31      Yes                 1
# 32       No                 0
# 33      Yes                 1
# 34       No                 0
# 35      Yes                 1
# 36       No                 0
# 37      Yes                 1
# 38       No                 0
# 39      Yes                 1
# 40       No                 0
# 41      Yes                 1
# 42       No                 0
# 43      Yes                 1
# 44       No                 0
# 45      Yes                 1
# 46       No                 0
# 47      Yes                 1
# 48       No                 0
# 49      Yes                 1
# 50       No                 0
# 51      Yes                 1
# 52       No                 0
# 53      Yes                 1
# 54       No                 0
# 55      Yes                 1
# 56       No                 0
# 57      Yes                 1
# 58       No                 0
# 59      Yes                 1
# 60       No                 0
# 61      Yes                 1
# 62       No                 0
# 63      Yes                 1
# 64       No                 0
# 65      Yes                 1
# 66       No                 0
# 67      Yes                 1
# 68       No                 0
# 69      Yes                 1
# 70       No                 0
# 71      Yes                 1
# 72       No                 0
# 73      Yes                 1
# 74       No                 0
# 75      Yes                 1
# 76       No                 0
# 77      Yes                 1
# 78       No                 0
# 79      Yes                 1
# 80       No                 0
# 81      Yes                 1
# 82       No                 0
# 83      Yes                 1
# 84       No                 0
# 85      Yes                 1
# 86       No                 0
# 87      Yes                 1
# 88       No                 0
# 89      Yes                 1
# 90       No                 0
# 91      Yes                 1
# 92       No                 0
# 93      Yes                 1
# 94       No                 0
# 95      Yes                 1
# 96       No                 0
# 97      Yes                 1
# 98       No                 0
# 99      Yes                 1
#
#
# Original Sample Data:
# =====================
#
#     PClass  Gender Sibling     Embarked Survived  encoded_survived
# 0    Third    Male     One  Southampton       No                 0
# 1   Second  Female    Zero  Southampton      Yes                 1
# 2    Third    Male    Zero  Southampton       No                 0
# 3    Third  Female   Three  Southampton      Yes                 1
# 4    Third    Male    Zero   Queenstown       No                 0
# 5    First  Female   Three  Southampton      Yes                 1
# 6    Third    Male    Zero  Southampton       No                 0
# 7    Third    Male    Zero  Southampton      Yes                 1
# 8    First    Male    Zero  Southampton       No                 0
# 9   Second    Male    Zero  Southampton      Yes                 1
# 10   Third    Male     One   Queenstown       No                 0
# 11   First    Male    Zero    Cherbourg      Yes                 1
# 12   First    Male    Zero    Cherbourg       No                 0
# 13  Second  Female    Zero  Southampton      Yes                 1
# 14  Second    Male    Zero  Southampton       No                 0
# 15   Third    Male     One    Cherbourg      Yes                 1
# 16   Third    Male     Two    Cherbourg       No                 0
# 17   Third    Male    Zero  Southampton      Yes                 1
# 18   Third    Male    Zero  Southampton       No                 0
# 19   Third  Female     One    Cherbourg      Yes                 1
# 20   Third    Male    Zero    Cherbourg       No                 0
# 21   First  Female    Zero  Southampton      Yes                 1
# 22   First    Male    Zero    Cherbourg       No                 0
# 23  Second  Female    Zero  Southampton      Yes                 1
# 24   Third  Female     One  Southampton       No                 0
# 25   Third  Female    Zero  Southampton      Yes                 1
# 26   Third    Male    Zero  Southampton       No                 0
# 27   Third    Male    Zero  Southampton      Yes                 1
# 28   Third    Male    Zero  Southampton       No                 0
# 29   Third  Female     One   Queenstown      Yes                 1
# 30   Third  Female     Two  Southampton       No                 0
# 31   First  Female    Zero    Cherbourg      Yes                 1
# 32   Third    Male     Two  Southampton       No                 0
# 33   First  Female    Zero  Southampton      Yes                 1
# 34   First    Male     One    Cherbourg       No                 0
# 35   First  Female    Zero  Southampton      Yes                 1
# 36   First    Male     One  Southampton       No                 0
# 37   Third  Female     One   Queenstown      Yes                 1
# 38   Third  Female     One  Southampton       No                 0
# 39  Second  Female     One  Southampton      Yes                 1
# 40  Second  Female     One  Southampton       No                 0
# 41   Third  Female    Zero   Queenstown      Yes                 1
# 42   Third    Male    Zero    Cherbourg       No                 0
# 43   First  Female    Zero    Cherbourg      Yes                 1
# 44   Third    Male   Three  Southampton       No                 0
# 45   Third  Female     One  Southampton      Yes                 1
# 46   Third    Male    Zero  Southampton       No                 0
# 47   Third    Male    Zero  Southampton      Yes                 1
# 48   Third    Male     One  Southampton       No                 0
# 49  Second  Female    Zero  Southampton      Yes                 1
# 50   First    Male   Three  Southampton       No                 0
# 51   Third    Male    Zero  Southampton      Yes                 1
# 52   Third  Female     One  Southampton       No                 0
# 53  Second  Female    Zero  Southampton      Yes                 1
# 54   Third  Female   Three  Southampton       No                 0
# 55   Third  Female    Zero  Southampton      Yes                 1
# 56   Third  Female    Zero  Southampton       No                 0
# 57   Third  Female     One  Southampton      Yes                 1
# 58   Third    Male    Zero    Cherbourg       No                 0
# 59   Third    Male    Zero  Southampton      Yes                 1
# 60  Second    Male    Zero  Southampton       No                 0
# 61   First  Female     One  Southampton      Yes                 1
# 62   Third    Male   Three   Queenstown       No                 0
# 63   Third  Female    Zero   Queenstown      Yes                 1
# 64  Second  Female    Zero  Southampton       No                 0
# 65   Third  Female    Zero    Cherbourg      Yes                 1
# 66   Third    Male    Zero  Southampton       No                 0
# 67  Second    Male    Zero  Southampton      Yes                 1
# 68   Third    Male    Zero  Southampton       No                 0
# 69   First    Male    Zero  Southampton      Yes                 1
# 70   Third    Male    Zero  Southampton       No                 0
# 71  Second    Male     Two  Southampton      Yes                 1
# 72   Third    Male    Zero    Cherbourg       No                 0
# 73   Third  Female    Zero  Southampton      Yes                 1
# 74   Third  Female    Zero  Southampton       No                 0
# 75   First  Female     One  Southampton      Yes                 1
# 76   Third    Male     One  Southampton       No                 0
# 77  Second  Female    Zero  Southampton      Yes                 1
# 78   Third    Male    Zero  Southampton       No                 0
# 79   Third  Female     Two  Southampton      Yes                 1
# 80   Third    Male     Two  Southampton       No                 0
# 81   Third  Female    Zero  Southampton      Yes                 1
# 82   Third    Male    Zero  Southampton       No                 0
# 83   First    Male     One  Southampton      Yes                 1
# 84  Second    Male    Zero  Southampton       No                 0
# 85   Third  Female     One   Queenstown      Yes                 1
# 86  Second    Male    Zero  Southampton       No                 0
# 87   First  Female     One  Southampton      Yes                 1
# 88   Third    Male    Zero  Southampton       No                 0
# 89  Second  Female    Zero  Southampton      Yes                 1
# 90  Second    Male    Zero  Southampton       No                 0
# 91  Second  Female    Zero  Southampton      Yes                 1
# 92   Third    Male    Zero    Cherbourg       No                 0
# 93   First    Male     One  Southampton      Yes                 1
# 94   First    Male     One  Southampton       No                 0
# 95   Third    Male     One    Cherbourg      Yes                 1
# 96   Third    Male     One   Queenstown       No                 0
# 97   Third    Male     One  Southampton      Yes                 1
# 98  Second    Male     One  Southampton       No                 0
# 99   Third    Male     One  Southampton      Yes                 1
#
#
# Sample Data after Label Encoding of Output:
# ===========================================
#
#     PClass  Gender Sibling     Embarked  Survived  encoded_survived
# 0    Third    Male     One  Southampton         0                 0
# 1   Second  Female    Zero  Southampton         1                 1
# 2    Third    Male    Zero  Southampton         0                 0
# 3    Third  Female   Three  Southampton         1                 1
# 4    Third    Male    Zero   Queenstown         0                 0
# 5    First  Female   Three  Southampton         1                 1
# 6    Third    Male    Zero  Southampton         0                 0
# 7    Third    Male    Zero  Southampton         1                 1
# 8    First    Male    Zero  Southampton         0                 0
# 9   Second    Male    Zero  Southampton         1                 1
# 10   Third    Male     One   Queenstown         0                 0
# 11   First    Male    Zero    Cherbourg         1                 1
# 12   First    Male    Zero    Cherbourg         0                 0
# 13  Second  Female    Zero  Southampton         1                 1
# 14  Second    Male    Zero  Southampton         0                 0
# 15   Third    Male     One    Cherbourg         1                 1
# 16   Third    Male     Two    Cherbourg         0                 0
# 17   Third    Male    Zero  Southampton         1                 1
# 18   Third    Male    Zero  Southampton         0                 0
# 19   Third  Female     One    Cherbourg         1                 1
# 20   Third    Male    Zero    Cherbourg         0                 0
# 21   First  Female    Zero  Southampton         1                 1
# 22   First    Male    Zero    Cherbourg         0                 0
# 23  Second  Female    Zero  Southampton         1                 1
# 24   Third  Female     One  Southampton         0                 0
# 25   Third  Female    Zero  Southampton         1                 1
# 26   Third    Male    Zero  Southampton         0                 0
# 27   Third    Male    Zero  Southampton         1                 1
# 28   Third    Male    Zero  Southampton         0                 0
# 29   Third  Female     One   Queenstown         1                 1
# 30   Third  Female     Two  Southampton         0                 0
# 31   First  Female    Zero    Cherbourg         1                 1
# 32   Third    Male     Two  Southampton         0                 0
# 33   First  Female    Zero  Southampton         1                 1
# 34   First    Male     One    Cherbourg         0                 0
# 35   First  Female    Zero  Southampton         1                 1
# 36   First    Male     One  Southampton         0                 0
# 37   Third  Female     One   Queenstown         1                 1
# 38   Third  Female     One  Southampton         0                 0
# 39  Second  Female     One  Southampton         1                 1
# 40  Second  Female     One  Southampton         0                 0
# 41   Third  Female    Zero   Queenstown         1                 1
# 42   Third    Male    Zero    Cherbourg         0                 0
# 43   First  Female    Zero    Cherbourg         1                 1
# 44   Third    Male   Three  Southampton         0                 0
# 45   Third  Female     One  Southampton         1                 1
# 46   Third    Male    Zero  Southampton         0                 0
# 47   Third    Male    Zero  Southampton         1                 1
# 48   Third    Male     One  Southampton         0                 0
# 49  Second  Female    Zero  Southampton         1                 1
# 50   First    Male   Three  Southampton         0                 0
# 51   Third    Male    Zero  Southampton         1                 1
# 52   Third  Female     One  Southampton         0                 0
# 53  Second  Female    Zero  Southampton         1                 1
# 54   Third  Female   Three  Southampton         0                 0
# 55   Third  Female    Zero  Southampton         1                 1
# 56   Third  Female    Zero  Southampton         0                 0
# 57   Third  Female     One  Southampton         1                 1
# 58   Third    Male    Zero    Cherbourg         0                 0
# 59   Third    Male    Zero  Southampton         1                 1
# 60  Second    Male    Zero  Southampton         0                 0
# 61   First  Female     One  Southampton         1                 1
# 62   Third    Male   Three   Queenstown         0                 0
# 63   Third  Female    Zero   Queenstown         1                 1
# 64  Second  Female    Zero  Southampton         0                 0
# 65   Third  Female    Zero    Cherbourg         1                 1
# 66   Third    Male    Zero  Southampton         0                 0
# 67  Second    Male    Zero  Southampton         1                 1
# 68   Third    Male    Zero  Southampton         0                 0
# 69   First    Male    Zero  Southampton         1                 1
# 70   Third    Male    Zero  Southampton         0                 0
# 71  Second    Male     Two  Southampton         1                 1
# 72   Third    Male    Zero    Cherbourg         0                 0
# 73   Third  Female    Zero  Southampton         1                 1
# 74   Third  Female    Zero  Southampton         0                 0
# 75   First  Female     One  Southampton         1                 1
# 76   Third    Male     One  Southampton         0                 0
# 77  Second  Female    Zero  Southampton         1                 1
# 78   Third    Male    Zero  Southampton         0                 0
# 79   Third  Female     Two  Southampton         1                 1
# 80   Third    Male     Two  Southampton         0                 0
# 81   Third  Female    Zero  Southampton         1                 1
# 82   Third    Male    Zero  Southampton         0                 0
# 83   First    Male     One  Southampton         1                 1
# 84  Second    Male    Zero  Southampton         0                 0
# 85   Third  Female     One   Queenstown         1                 1
# 86  Second    Male    Zero  Southampton         0                 0
# 87   First  Female     One  Southampton         1                 1
# 88   Third    Male    Zero  Southampton         0                 0
# 89  Second  Female    Zero  Southampton         1                 1
# 90  Second    Male    Zero  Southampton         0                 0
# 91  Second  Female    Zero  Southampton         1                 1
# 92   Third    Male    Zero    Cherbourg         0                 0
# 93   First    Male     One  Southampton         1                 1
# 94   First    Male     One  Southampton         0                 0
# 95   Third    Male     One    Cherbourg         1                 1
# 96   Third    Male     One   Queenstown         0                 0
# 97   Third    Male     One  Southampton         1                 1
# 98  Second    Male     One  Southampton         0                 0
# 99   Third    Male     One  Southampton         1                 1

# %% [markdown]
# ## Step 5.3: Label Encode the Input

# %%
# Label Encoding of the Input

''' 
*------------------- LABEL_ENCODE_INPUT --------------------*
|        Function: Transform()                              |
|              Purpose: Transform Input (Categorical)       |
|                          into Numerical Representation    |
|        Arguments:                                         |
|              Attribute: Target values                     |
|        Return:                                            |
|              Attribute: Numerical Representation          |
*-----------------------------------------------------------*
'''

sample_data_encoded = sample_data_encoded_output.copy()
sample_data_encoded_output_orignal = sample_data_encoded_output.copy()

# Transform Input Attributes into Numerical Representation

print("\n\nPClass Attribute After Label Encoding:")
print("======================================\n")
sample_data_encoded_output["encoded_pclass"] = pclass_label_encoder.transform(sample_data_encoded_output['PClass'])
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded_output[["PClass", "encoded_pclass"]])

print("\n\nGender Attribute After Label Encoding:")
print("======================================\n")
sample_data_encoded_output["encoded_gender"] = gender_label_encoder.transform(sample_data_encoded_output['Gender'])
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded_output[["Gender", "encoded_gender"]])

print("\n\nSibling Attribute After Label Encoding:")
print("=======================================\n")
sample_data_encoded_output["encoded_sibling"] = sibling_label_encoder.transform(sample_data_encoded_output['Sibling'])
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded_output[["Sibling", "encoded_sibling"]])

print("\n\nEmbarked Attribute After Label Encoding:")
print("========================================\n")
sample_data_encoded_output["encoded_embarked"] = embarked_label_encoder.transform(sample_data_encoded_output['Embarked'])
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded_output[["Embarked", "encoded_embarked"]])

# Print Original and Encoded Sample Data

sample_data_encoded[['PClass', 'Gender', 'Sibling', 'Embarked', 'Survived']] = sample_data_encoded_output[['encoded_pclass', 'encoded_gender', 'encoded_sibling', 'encoded_embarked', 'Survived']]
print("\n\nOriginal Sample Data:")
print("=====================\n")
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(original_sample_data)
print("\n\nSample Data after Label Encoding:")
print("=================================\n")
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sample_data_encoded)

# Save the Transformed Features into CSV File 

sample_data_encoded.to_csv(r'sample-data-encoded.csv', index = False, header = True)
# Out:
# PClass Attribute After Label Encoding:
# ======================================
#
#     PClass  encoded_pclass
# 0    Third               2
# 1   Second               1
# 2    Third               2
# 3    Third               2
# 4    Third               2
# 5    First               0
# 6    Third               2
# 7    Third               2
# 8    First               0
# 9   Second               1
# 10   Third               2
# 11   First               0
# 12   First               0
# 13  Second               1
# 14  Second               1
# 15   Third               2
# 16   Third               2
# 17   Third               2
# 18   Third               2
# 19   Third               2
# 20   Third               2
# 21   First               0
# 22   First               0
# 23  Second               1
# 24   Third               2
# 25   Third               2
# 26   Third               2
# 27   Third               2
# 28   Third               2
# 29   Third               2
# 30   Third               2
# 31   First               0
# 32   Third               2
# 33   First               0
# 34   First               0
# 35   First               0
# 36   First               0
# 37   Third               2
# 38   Third               2
# 39  Second               1
# 40  Second               1
# 41   Third               2
# 42   Third               2
# 43   First               0
# 44   Third               2
# 45   Third               2
# 46   Third               2
# 47   Third               2
# 48   Third               2
# 49  Second               1
# 50   First               0
# 51   Third               2
# 52   Third               2
# 53  Second               1
# 54   Third               2
# 55   Third               2
# 56   Third               2
# 57   Third               2
# 58   Third               2
# 59   Third               2
# 60  Second               1
# 61   First               0
# 62   Third               2
# 63   Third               2
# 64  Second               1
# 65   Third               2
# 66   Third               2
# 67  Second               1
# 68   Third               2
# 69   First               0
# 70   Third               2
# 71  Second               1
# 72   Third               2
# 73   Third               2
# 74   Third               2
# 75   First               0
# 76   Third               2
# 77  Second               1
# 78   Third               2
# 79   Third               2
# 80   Third               2
# 81   Third               2
# 82   Third               2
# 83   First               0
# 84  Second               1
# 85   Third               2
# 86  Second               1
# 87   First               0
# 88   Third               2
# 89  Second               1
# 90  Second               1
# 91  Second               1
# 92   Third               2
# 93   First               0
# 94   First               0
# 95   Third               2
# 96   Third               2
# 97   Third               2
# 98  Second               1
# 99   Third               2
#
#
# Gender Attribute After Label Encoding:
# ======================================
#
#     Gender  encoded_gender
# 0     Male               1
# 1   Female               0
# 2     Male               1
# 3   Female               0
# 4     Male               1
# 5   Female               0
# 6     Male               1
# 7     Male               1
# 8     Male               1
# 9     Male               1
# 10    Male               1
# 11    Male               1
# 12    Male               1
# 13  Female               0
# 14    Male               1
# 15    Male               1
# 16    Male               1
# 17    Male               1
# 18    Male               1
# 19  Female               0
# 20    Male               1
# 21  Female               0
# 22    Male               1
# 23  Female               0
# 24  Female               0
# 25  Female               0
# 26    Male               1
# 27    Male               1
# 28    Male               1
# 29  Female               0
# 30  Female               0
# 31  Female               0
# 32    Male               1
# 33  Female               0
# 34    Male               1
# 35  Female               0
# 36    Male               1
# 37  Female               0
# 38  Female               0
# 39  Female               0
# 40  Female               0
# 41  Female               0
# 42    Male               1
# 43  Female               0
# 44    Male               1
# 45  Female               0
# 46    Male               1
# 47    Male               1
# 48    Male               1
# 49  Female               0
# 50    Male               1
# 51    Male               1
# 52  Female               0
# 53  Female               0
# 54  Female               0
# 55  Female               0
# 56  Female               0
# 57  Female               0
# 58    Male               1
# 59    Male               1
# 60    Male               1
# 61  Female               0
# 62    Male               1
# 63  Female               0
# 64  Female               0
# 65  Female               0
# 66    Male               1
# 67    Male               1
# 68    Male               1
# 69    Male               1
# 70    Male               1
# 71    Male               1
# 72    Male               1
# 73  Female               0
# 74  Female               0
# 75  Female               0
# 76    Male               1
# 77  Female               0
# 78    Male               1
# 79  Female               0
# 80    Male               1
# 81  Female               0
# 82    Male               1
# 83    Male               1
# 84    Male               1
# 85  Female               0
# 86    Male               1
# 87  Female               0
# 88    Male               1
# 89  Female               0
# 90    Male               1
# 91  Female               0
# 92    Male               1
# 93    Male               1
# 94    Male               1
# 95    Male               1
# 96    Male               1
# 97    Male               1
# 98    Male               1
# 99    Male               1
#
#
# Sibling Attribute After Label Encoding:
# =======================================
#
#    Sibling  encoded_sibling
# 0      One                0
# 1     Zero                3
# 2     Zero                3
# 3    Three                1
# 4     Zero                3
# 5    Three                1
# 6     Zero                3
# 7     Zero                3
# 8     Zero                3
# 9     Zero                3
# 10     One                0
# 11    Zero                3
# 12    Zero                3
# 13    Zero                3
# 14    Zero                3
# 15     One                0
# 16     Two                2
# 17    Zero                3
# 18    Zero                3
# 19     One                0
# 20    Zero                3
# 21    Zero                3
# 22    Zero                3
# 23    Zero                3
# 24     One                0
# 25    Zero                3
# 26    Zero                3
# 27    Zero                3
# 28    Zero                3
# 29     One                0
# 30     Two                2
# 31    Zero                3
# 32     Two                2
# 33    Zero                3
# 34     One                0
# 35    Zero                3
# 36     One                0
# 37     One                0
# 38     One                0
# 39     One                0
# 40     One                0
# 41    Zero                3
# 42    Zero                3
# 43    Zero                3
# 44   Three                1
# 45     One                0
# 46    Zero                3
# 47    Zero                3
# 48     One                0
# 49    Zero                3
# 50   Three                1
# 51    Zero                3
# 52     One                0
# 53    Zero                3
# 54   Three                1
# 55    Zero                3
# 56    Zero                3
# 57     One                0
# 58    Zero                3
# 59    Zero                3
# 60    Zero                3
# 61     One                0
# 62   Three                1
# 63    Zero                3
# 64    Zero                3
# 65    Zero                3
# 66    Zero                3
# 67    Zero                3
# 68    Zero                3
# 69    Zero                3
# 70    Zero                3
# 71     Two                2
# 72    Zero                3
# 73    Zero                3
# 74    Zero                3
# 75     One                0
# 76     One                0
# 77    Zero                3
# 78    Zero                3
# 79     Two                2
# 80     Two                2
# 81    Zero                3
# 82    Zero                3
# 83     One                0
# 84    Zero                3
# 85     One                0
# 86    Zero                3
# 87     One                0
# 88    Zero                3
# 89    Zero                3
# 90    Zero                3
# 91    Zero                3
# 92    Zero                3
# 93     One                0
# 94     One                0
# 95     One                0
# 96     One                0
# 97     One                0
# 98     One                0
# 99     One                0
#
#
# Embarked Attribute After Label Encoding:
# ========================================
#
#        Embarked  encoded_embarked
# 0   Southampton                 2
# 1   Southampton                 2
# 2   Southampton                 2
# 3   Southampton                 2
# 4    Queenstown                 1
# 5   Southampton                 2
# 6   Southampton                 2
# 7   Southampton                 2
# 8   Southampton                 2
# 9   Southampton                 2
# 10   Queenstown                 1
# 11    Cherbourg                 0
# 12    Cherbourg                 0
# 13  Southampton                 2
# 14  Southampton                 2
# 15    Cherbourg                 0
# 16    Cherbourg                 0
# 17  Southampton                 2
# 18  Southampton                 2
# 19    Cherbourg                 0
# 20    Cherbourg                 0
# 21  Southampton                 2
# 22    Cherbourg                 0
# 23  Southampton                 2
# 24  Southampton                 2
# 25  Southampton                 2
# 26  Southampton                 2
# 27  Southampton                 2
# 28  Southampton                 2
# 29   Queenstown                 1
# 30  Southampton                 2
# 31    Cherbourg                 0
# 32  Southampton                 2
# 33  Southampton                 2
# 34    Cherbourg                 0
# 35  Southampton                 2
# 36  Southampton                 2
# 37   Queenstown                 1
# 38  Southampton                 2
# 39  Southampton                 2
# 40  Southampton                 2
# 41   Queenstown                 1
# 42    Cherbourg                 0
# 43    Cherbourg                 0
# 44  Southampton                 2
# 45  Southampton                 2
# 46  Southampton                 2
# 47  Southampton                 2
# 48  Southampton                 2
# 49  Southampton                 2
# 50  Southampton                 2
# 51  Southampton                 2
# 52  Southampton                 2
# 53  Southampton                 2
# 54  Southampton                 2
# 55  Southampton                 2
# 56  Southampton                 2
# 57  Southampton                 2
# 58    Cherbourg                 0
# 59  Southampton                 2
# 60  Southampton                 2
# 61  Southampton                 2
# 62   Queenstown                 1
# 63   Queenstown                 1
# 64  Southampton                 2
# 65    Cherbourg                 0
# 66  Southampton                 2
# 67  Southampton                 2
# 68  Southampton                 2
# 69  Southampton                 2
# 70  Southampton                 2
# 71  Southampton                 2
# 72    Cherbourg                 0
# 73  Southampton                 2
# 74  Southampton                 2
# 75  Southampton                 2
# 76  Southampton                 2
# 77  Southampton                 2
# 78  Southampton                 2
# 79  Southampton                 2
# 80  Southampton                 2
# 81  Southampton                 2
# 82  Southampton                 2
# 83  Southampton                 2
# 84  Southampton                 2
# 85   Queenstown                 1
# 86  Southampton                 2
# 87  Southampton                 2
# 88  Southampton                 2
# 89  Southampton                 2
# 90  Southampton                 2
# 91  Southampton                 2
# 92    Cherbourg                 0
# 93  Southampton                 2
# 94  Southampton                 2
# 95    Cherbourg                 0
# 96   Queenstown                 1
# 97  Southampton                 2
# 98  Southampton                 2
# 99  Southampton                 2
#
#
# Original Sample Data:
# =====================
#
#     PClass  Gender Sibling     Embarked Survived  encoded_survived
# 0    Third    Male     One  Southampton       No                 0
# 1   Second  Female    Zero  Southampton      Yes                 1
# 2    Third    Male    Zero  Southampton       No                 0
# 3    Third  Female   Three  Southampton      Yes                 1
# 4    Third    Male    Zero   Queenstown       No                 0
# 5    First  Female   Three  Southampton      Yes                 1
# 6    Third    Male    Zero  Southampton       No                 0
# 7    Third    Male    Zero  Southampton      Yes                 1
# 8    First    Male    Zero  Southampton       No                 0
# 9   Second    Male    Zero  Southampton      Yes                 1
# 10   Third    Male     One   Queenstown       No                 0
# 11   First    Male    Zero    Cherbourg      Yes                 1
# 12   First    Male    Zero    Cherbourg       No                 0
# 13  Second  Female    Zero  Southampton      Yes                 1
# 14  Second    Male    Zero  Southampton       No                 0
# 15   Third    Male     One    Cherbourg      Yes                 1
# 16   Third    Male     Two    Cherbourg       No                 0
# 17   Third    Male    Zero  Southampton      Yes                 1
# 18   Third    Male    Zero  Southampton       No                 0
# 19   Third  Female     One    Cherbourg      Yes                 1
# 20   Third    Male    Zero    Cherbourg       No                 0
# 21   First  Female    Zero  Southampton      Yes                 1
# 22   First    Male    Zero    Cherbourg       No                 0
# 23  Second  Female    Zero  Southampton      Yes                 1
# 24   Third  Female     One  Southampton       No                 0
# 25   Third  Female    Zero  Southampton      Yes                 1
# 26   Third    Male    Zero  Southampton       No                 0
# 27   Third    Male    Zero  Southampton      Yes                 1
# 28   Third    Male    Zero  Southampton       No                 0
# 29   Third  Female     One   Queenstown      Yes                 1
# 30   Third  Female     Two  Southampton       No                 0
# 31   First  Female    Zero    Cherbourg      Yes                 1
# 32   Third    Male     Two  Southampton       No                 0
# 33   First  Female    Zero  Southampton      Yes                 1
# 34   First    Male     One    Cherbourg       No                 0
# 35   First  Female    Zero  Southampton      Yes                 1
# 36   First    Male     One  Southampton       No                 0
# 37   Third  Female     One   Queenstown      Yes                 1
# 38   Third  Female     One  Southampton       No                 0
# 39  Second  Female     One  Southampton      Yes                 1
# 40  Second  Female     One  Southampton       No                 0
# 41   Third  Female    Zero   Queenstown      Yes                 1
# 42   Third    Male    Zero    Cherbourg       No                 0
# 43   First  Female    Zero    Cherbourg      Yes                 1
# 44   Third    Male   Three  Southampton       No                 0
# 45   Third  Female     One  Southampton      Yes                 1
# 46   Third    Male    Zero  Southampton       No                 0
# 47   Third    Male    Zero  Southampton      Yes                 1
# 48   Third    Male     One  Southampton       No                 0
# 49  Second  Female    Zero  Southampton      Yes                 1
# 50   First    Male   Three  Southampton       No                 0
# 51   Third    Male    Zero  Southampton      Yes                 1
# 52   Third  Female     One  Southampton       No                 0
# 53  Second  Female    Zero  Southampton      Yes                 1
# 54   Third  Female   Three  Southampton       No                 0
# 55   Third  Female    Zero  Southampton      Yes                 1
# 56   Third  Female    Zero  Southampton       No                 0
# 57   Third  Female     One  Southampton      Yes                 1
# 58   Third    Male    Zero    Cherbourg       No                 0
# 59   Third    Male    Zero  Southampton      Yes                 1
# 60  Second    Male    Zero  Southampton       No                 0
# 61   First  Female     One  Southampton      Yes                 1
# 62   Third    Male   Three   Queenstown       No                 0
# 63   Third  Female    Zero   Queenstown      Yes                 1
# 64  Second  Female    Zero  Southampton       No                 0
# 65   Third  Female    Zero    Cherbourg      Yes                 1
# 66   Third    Male    Zero  Southampton       No                 0
# 67  Second    Male    Zero  Southampton      Yes                 1
# 68   Third    Male    Zero  Southampton       No                 0
# 69   First    Male    Zero  Southampton      Yes                 1
# 70   Third    Male    Zero  Southampton       No                 0
# 71  Second    Male     Two  Southampton      Yes                 1
# 72   Third    Male    Zero    Cherbourg       No                 0
# 73   Third  Female    Zero  Southampton      Yes                 1
# 74   Third  Female    Zero  Southampton       No                 0
# 75   First  Female     One  Southampton      Yes                 1
# 76   Third    Male     One  Southampton       No                 0
# 77  Second  Female    Zero  Southampton      Yes                 1
# 78   Third    Male    Zero  Southampton       No                 0
# 79   Third  Female     Two  Southampton      Yes                 1
# 80   Third    Male     Two  Southampton       No                 0
# 81   Third  Female    Zero  Southampton      Yes                 1
# 82   Third    Male    Zero  Southampton       No                 0
# 83   First    Male     One  Southampton      Yes                 1
# 84  Second    Male    Zero  Southampton       No                 0
# 85   Third  Female     One   Queenstown      Yes                 1
# 86  Second    Male    Zero  Southampton       No                 0
# 87   First  Female     One  Southampton      Yes                 1
# 88   Third    Male    Zero  Southampton       No                 0
# 89  Second  Female    Zero  Southampton      Yes                 1
# 90  Second    Male    Zero  Southampton       No                 0
# 91  Second  Female    Zero  Southampton      Yes                 1
# 92   Third    Male    Zero    Cherbourg       No                 0
# 93   First    Male     One  Southampton      Yes                 1
# 94   First    Male     One  Southampton       No                 0
# 95   Third    Male     One    Cherbourg      Yes                 1
# 96   Third    Male     One   Queenstown       No                 0
# 97   Third    Male     One  Southampton      Yes                 1
# 98  Second    Male     One  Southampton       No                 0
# 99   Third    Male     One  Southampton      Yes                 1
#
#
# Sample Data after Label Encoding:
# =================================
#
#     PClass  Gender  Sibling  Embarked  Survived  encoded_survived
# 0        2       1        0         2         0                 0
# 1        1       0        3         2         1                 1
# 2        2       1        3         2         0                 0
# 3        2       0        1         2         1                 1
# 4        2       1        3         1         0                 0
# 5        0       0        1         2         1                 1
# 6        2       1        3         2         0                 0
# 7        2       1        3         2         1                 1
# 8        0       1        3         2         0                 0
# 9        1       1        3         2         1                 1
# 10       2       1        0         1         0                 0
# 11       0       1        3         0         1                 1
# 12       0       1        3         0         0                 0
# 13       1       0        3         2         1                 1
# 14       1       1        3         2         0                 0
# 15       2       1        0         0         1                 1
# 16       2       1        2         0         0                 0
# 17       2       1        3         2         1                 1
# 18       2       1        3         2         0                 0
# 19       2       0        0         0         1                 1
# 20       2       1        3         0         0                 0
# 21       0       0        3         2         1                 1
# 22       0       1        3         0         0                 0
# 23       1       0        3         2         1                 1
# 24       2       0        0         2         0                 0
# 25       2       0        3         2         1                 1
# 26       2       1        3         2         0                 0
# 27       2       1        3         2         1                 1
# 28       2       1        3         2         0                 0
# 29       2       0        0         1         1                 1
# 30       2       0        2         2         0                 0
# 31       0       0        3         0         1                 1
# 32       2       1        2         2         0                 0
# 33       0       0        3         2         1                 1
# 34       0       1        0         0         0                 0
# 35       0       0        3         2         1                 1
# 36       0       1        0         2         0                 0
# 37       2       0        0         1         1                 1
# 38       2       0        0         2         0                 0
# 39       1       0        0         2         1                 1
# 40       1       0        0         2         0                 0
# 41       2       0        3         1         1                 1
# 42       2       1        3         0         0                 0
# 43       0       0        3         0         1                 1
# 44       2       1        1         2         0                 0
# 45       2       0        0         2         1                 1
# 46       2       1        3         2         0                 0
# 47       2       1        3         2         1                 1
# 48       2       1        0         2         0                 0
# 49       1       0        3         2         1                 1
# 50       0       1        1         2         0                 0
# 51       2       1        3         2         1                 1
# 52       2       0        0         2         0                 0
# 53       1       0        3         2         1                 1
# 54       2       0        1         2         0                 0
# 55       2       0        3         2         1                 1
# 56       2       0        3         2         0                 0
# 57       2       0        0         2         1                 1
# 58       2       1        3         0         0                 0
# 59       2       1        3         2         1                 1
# 60       1       1        3         2         0                 0
# 61       0       0        0         2         1                 1
# 62       2       1        1         1         0                 0
# 63       2       0        3         1         1                 1
# 64       1       0        3         2         0                 0
# 65       2       0        3         0         1                 1
# 66       2       1        3         2         0                 0
# 67       1       1        3         2         1                 1
# 68       2       1        3         2         0                 0
# 69       0       1        3         2         1                 1
# 70       2       1        3         2         0                 0
# 71       1       1        2         2         1                 1
# 72       2       1        3         0         0                 0
# 73       2       0        3         2         1                 1
# 74       2       0        3         2         0                 0
# 75       0       0        0         2         1                 1
# 76       2       1        0         2         0                 0
# 77       1       0        3         2         1                 1
# 78       2       1        3         2         0                 0
# 79       2       0        2         2         1                 1
# 80       2       1        2         2         0                 0
# 81       2       0        3         2         1                 1
# 82       2       1        3         2         0                 0
# 83       0       1        0         2         1                 1
# 84       1       1        3         2         0                 0
# 85       2       0        0         1         1                 1
# 86       1       1        3         2         0                 0
# 87       0       0        0         2         1                 1
# 88       2       1        3         2         0                 0
# 89       1       0        3         2         1                 1
# 90       1       1        3         2         0                 0
# 91       1       0        3         2         1                 1
# 92       2       1        3         0         0                 0
# 93       0       1        0         2         1                 1
# 94       0       1        0         2         0                 0
# 95       2       1        0         0         1                 1
# 96       2       1        0         1         0                 0
# 97       2       1        0         2         1                 1
# 98       1       1        0         2         0                 0
# 99       2       1        0         2         1                 1

# %% [markdown]
# # Step 6: Execute the Training Phase

# %% [markdown]
# ## Step 6.1: Splitting Sample Data into Training Data and Testing Data

# %%
# Splitting Sample Data into Training Data and Testing Data

''' 
*------------------- SPLIT_SAMPLE_DATA ---------------------*
|        Function: train_test_split()                       |
|              Purpose: Split arrays or matrices into       |
|                       random train and test subsets       |
|        Arguments:                                         |
|              arrays: sequence of indexables               |
|              test_size: float or int                      |
|        Return:                                            |
|              splitting: list                              |
*-----------------------------------------------------------*
'''

training_data_encoded, testing_data_encoded = train_test_split( sample_data_encoded , test_size=0.2 , random_state=0 , shuffle = False)

# # Save the Training and Testing Data into CSV File 

# training_data_encoded.to_csv(r'training-data-encoded.csv', index = False, header = True)
# testing_data_encoded.to_csv(r'testing-data-encoded.csv', index = False, header = True)

# # print Training and Testing Data

# print("\n\nTraining Data:")
# print("==============\n")
# pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(training_data_encoded)
# print("\n\nTesting Data:")
# print("==============\n")
# pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(testing_data_encoded)

print("\n\nInputs Vectors (Feature Vectors) of Training Data:")
print("==================================================\n")

# Possible names for the original/encoded target columns (add other variants if you use them)
target_candidates = ["Survived", "Survived_encoded", "encoded_survived"]

# Determine which target column to use as the label (prefer encoded names first)
label_col = None
for name in ("Survived_encoded", "encoded_survived", "Survived"):
    if name in training_data_encoded.columns:
        label_col = name
        break

# Build a list of exactly two columns to drop:
# - If we found an encoded label (Survived_encoded / encoded_survived) drop both that and 'Survived' if present
# - If only 'Survived' exists, drop it (and any other explicit variant found)
cols_to_drop = []
if label_col:
    cols_to_drop.append(label_col)
# Also try to drop the plain 'Survived' column (if it's not already included)
if "Survived" in training_data_encoded.columns and "Survived" not in cols_to_drop:
    cols_to_drop.append("Survived")

# If you want to strictly ensure exactly two columns are dropped but only one was found, you can extend this list
# with any other known variant or simply rely on errors='ignore' below.
input_vector_train = training_data_encoded.drop(columns=cols_to_drop, errors='ignore')

print(f"Dropped columns: {cols_to_drop}")
print(input_vector_train)

print("\n\nOutputs/Labels of Training Data:")
print("================================\n")
if label_col:
    output_label_train = training_data_encoded[label_col]
else:
    raise KeyError("No target column found. Expected one of: " + ", ".join(target_candidates))

print(output_label_train)
# Out:
# Inputs Vectors (Feature Vectors) of Training Data:
# ==================================================
#
# Dropped columns: ['encoded_survived', 'Survived']
#     PClass  Gender  Sibling  Embarked
# 0        2       1        0         2
# 1        1       0        3         2
# 2        2       1        3         2
# 3        2       0        1         2
# 4        2       1        3         1
# 5        0       0        1         2
# 6        2       1        3         2
# 7        2       1        3         2
# 8        0       1        3         2
# 9        1       1        3         2
# 10       2       1        0         1
# 11       0       1        3         0
# 12       0       1        3         0
# 13       1       0        3         2
# 14       1       1        3         2
# 15       2       1        0         0
# 16       2       1        2         0
# 17       2       1        3         2
# 18       2       1        3         2
# 19       2       0        0         0
# 20       2       1        3         0
# 21       0       0        3         2
# 22       0       1        3         0
# 23       1       0        3         2
# 24       2       0        0         2
# 25       2       0        3         2
# 26       2       1        3         2
# 27       2       1        3         2
# 28       2       1        3         2
# 29       2       0        0         1
# 30       2       0        2         2
# 31       0       0        3         0
# 32       2       1        2         2
# 33       0       0        3         2
# 34       0       1        0         0
# 35       0       0        3         2
# 36       0       1        0         2
# 37       2       0        0         1
# 38       2       0        0         2
# 39       1       0        0         2
# 40       1       0        0         2
# 41       2       0        3         1
# 42       2       1        3         0
# 43       0       0        3         0
# 44       2       1        1         2
# 45       2       0        0         2
# 46       2       1        3         2
# 47       2       1        3         2
# 48       2       1        0         2
# 49       1       0        3         2
# 50       0       1        1         2
# 51       2       1        3         2
# 52       2       0        0         2
# 53       1       0        3         2
# 54       2       0        1         2
# 55       2       0        3         2
# 56       2       0        3         2
# 57       2       0        0         2
# 58       2       1        3         0
# 59       2       1        3         2
# 60       1       1        3         2
# 61       0       0        0         2
# 62       2       1        1         1
# 63       2       0        3         1
# 64       1       0        3         2
# 65       2       0        3         0
# 66       2       1        3         2
# 67       1       1        3         2
# 68       2       1        3         2
# 69       0       1        3         2
# 70       2       1        3         2
# 71       1       1        2         2
# 72       2       1        3         0
# 73       2       0        3         2
# 74       2       0        3         2
# 75       0       0        0         2
# 76       2       1        0         2
# 77       1       0        3         2
# 78       2       1        3         2
# 79       2       0        2         2
#
#
# Outputs/Labels of Training Data:
# ================================
#
# 0     0
# 1     1
# 2     0
# 3     1
# 4     0
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    0
# 15    1
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    0
# 23    1
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    1
# 30    0
# 31    1
# 32    0
# 33    1
# 34    0
# 35    1
# 36    0
# 37    1
# 38    0
# 39    1
# 40    0
# 41    1
# 42    0
# 43    1
# 44    0
# 45    1
# 46    0
# 47    1
# 48    0
# 49    1
# 50    0
# 51    1
# 52    0
# 53    1
# 54    0
# 55    1
# 56    0
# 57    1
# 58    0
# 59    1
# 60    0
# 61    1
# 62    0
# 63    1
# 64    0
# 65    1
# 66    0
# 67    1
# 68    0
# 69    1
# 70    0
# 71    1
# 72    0
# 73    1
# 74    0
# 75    1
# 76    0
# 77    1
# 78    0
# 79    1
# Name: encoded_survived, dtype: int64

# %% [markdown]
# ## Step 6.2: Splitting Input Vectors and Outputs / Labels of Training Data

# %%
# Splitting Input Vectors and Outputs / Labels of Training Data

'''
*---------------- SPLIT_INPUT_VECTORS_AND_LABELS --------------*
|        Function: iloc()                                      |
|            Purpose: Splitting Input Vector and Labels        |
|        Arguments:                                            |
|            Attribute: Name or Location Attribute to Split    |
|        Return:                                               |
|            Attribute: Split Attributes                       |
*--------------------------------------------------------------*
'''

print("\n\nInputs Vectors (Feature Vectors) of Training Data:")
print("==================================================\n")
# input_vector_train = training_data_encoded.iloc[: , :-1]
input_vector_train = training_data_encoded.drop(columns=["Survived", "encoded_survived"], errors='ignore')

print(input_vector_train)

print("\n\nOutputs/Labels of Training Data:")
print("================================\n")
print("  Survived")
output_label_train = training_data_encoded.iloc[: ,-1]
print(output_label_train)
# Out:
# Inputs Vectors (Feature Vectors) of Training Data:
# ==================================================
#
#     PClass  Gender  Sibling  Embarked
# 0        2       1        0         2
# 1        1       0        3         2
# 2        2       1        3         2
# 3        2       0        1         2
# 4        2       1        3         1
# 5        0       0        1         2
# 6        2       1        3         2
# 7        2       1        3         2
# 8        0       1        3         2
# 9        1       1        3         2
# 10       2       1        0         1
# 11       0       1        3         0
# 12       0       1        3         0
# 13       1       0        3         2
# 14       1       1        3         2
# 15       2       1        0         0
# 16       2       1        2         0
# 17       2       1        3         2
# 18       2       1        3         2
# 19       2       0        0         0
# 20       2       1        3         0
# 21       0       0        3         2
# 22       0       1        3         0
# 23       1       0        3         2
# 24       2       0        0         2
# 25       2       0        3         2
# 26       2       1        3         2
# 27       2       1        3         2
# 28       2       1        3         2
# 29       2       0        0         1
# 30       2       0        2         2
# 31       0       0        3         0
# 32       2       1        2         2
# 33       0       0        3         2
# 34       0       1        0         0
# 35       0       0        3         2
# 36       0       1        0         2
# 37       2       0        0         1
# 38       2       0        0         2
# 39       1       0        0         2
# 40       1       0        0         2
# 41       2       0        3         1
# 42       2       1        3         0
# 43       0       0        3         0
# 44       2       1        1         2
# 45       2       0        0         2
# 46       2       1        3         2
# 47       2       1        3         2
# 48       2       1        0         2
# 49       1       0        3         2
# 50       0       1        1         2
# 51       2       1        3         2
# 52       2       0        0         2
# 53       1       0        3         2
# 54       2       0        1         2
# 55       2       0        3         2
# 56       2       0        3         2
# 57       2       0        0         2
# 58       2       1        3         0
# 59       2       1        3         2
# 60       1       1        3         2
# 61       0       0        0         2
# 62       2       1        1         1
# 63       2       0        3         1
# 64       1       0        3         2
# 65       2       0        3         0
# 66       2       1        3         2
# 67       1       1        3         2
# 68       2       1        3         2
# 69       0       1        3         2
# 70       2       1        3         2
# 71       1       1        2         2
# 72       2       1        3         0
# 73       2       0        3         2
# 74       2       0        3         2
# 75       0       0        0         2
# 76       2       1        0         2
# 77       1       0        3         2
# 78       2       1        3         2
# 79       2       0        2         2
#
#
# Outputs/Labels of Training Data:
# ================================
#
#   Survived
# 0     0
# 1     1
# 2     0
# 3     1
# 4     0
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    0
# 15    1
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    0
# 23    1
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    1
# 30    0
# 31    1
# 32    0
# 33    1
# 34    0
# 35    1
# 36    0
# 37    1
# 38    0
# 39    1
# 40    0
# 41    1
# 42    0
# 43    1
# 44    0
# 45    1
# 46    0
# 47    1
# 48    0
# 49    1
# 50    0
# 51    1
# 52    0
# 53    1
# 54    0
# 55    1
# 56    0
# 57    1
# 58    0
# 59    1
# 60    0
# 61    1
# 62    0
# 63    1
# 64    0
# 65    1
# 66    0
# 67    1
# 68    0
# 69    1
# 70    0
# 71    1
# 72    0
# 73    1
# 74    0
# 75    1
# 76    0
# 77    1
# 78    0
# 79    1
# Name: encoded_survived, dtype: int64

# %% [markdown]
# ## 6.3: Train the Support Vector Classifier

# %%
# Train the Support Vector Classifier

''' 
*--------------- TRAIN_SUPPORT_VECTOR_CLASSIFIER ------------------*
|       Function: svm.SVC()                                        |
|           Purpose: Train the Algorithm on Training Data          |
|       Arguments:                                                 |
|           Training Data: Provide Training Data to the Model      |
|       Return:                                                    |
|           Parameter: Model return the Training Parameters        |
*------------------------------------------------------------------*
'''

print("\n\nTraining the Support Vector Classifier on Training Data")
print("========================================================\n")
print("\nParameters and their values:")
print("============================\n")
svc_model = svm.SVC(gamma='auto',random_state=0)
svc_model.fit(input_vector_train,np.ravel(output_label_train))
print(svc_model)
# Out:
# Training the Support Vector Classifier on Training Data
# ========================================================
#
#
# Parameters and their values:
# ============================
#
# SVC(gamma='auto', random_state=0)

# %% [markdown]
# ## Step 6.4: Save the Trained Model

# %%
# Save the Trained Model

''' 
*--------------------- SAVE_THE_TRAINED_MODEL ---------------------*
|        Function: dump()                                          |
|             Purpose: Save the Trained Model on your Hard Disk    |
|        Arguments:                                                |
|             Model: Model Objects                                 |
|        Return:                                                   |
|             File: Trained Model will be Saved on Hard Disk       |
*------------------------------------------------------------------* 
'''

# Save the Model in a Pkl File

pickle.dump(svc_model, open('svc_trained_model.pkl', 'wb'))

# %% [markdown]
# # Step 7: Execute the Testing Phase

# %% [markdown]
# ## Step 7.1: Splitting Input Vectors and Outputs/Labels of Testing Data

# %%
# Splitting Input Vectors and Outputs/Labels of Testing Data

'''
*---------------- SPLIT_INPUT_VECTORS_AND_LABELS --------------*
|        Function: iloc()                                      |
|            Purpose: Splitting Input Vector and Labels        |
|        Arguments:                                            |
|            Attribute: Name or Location Attribute to Split    |
|        Return:                                               |
|            Attribute: Split Attributes                       |
*--------------------------------------------------------------*
'''

print("\n\nInputs Vectors (Feature Vectors) of Testing Data:")
print("=================================================\n")
# input_vector_test = testing_data_encoded.iloc[: , :-1]
input_vector_test = testing_data_encoded.drop(columns=["Survived", "encoded_survived"], errors='ignore')
print(input_vector_test)

print("\n\nOutputs/Labels of Testing Data:")
print("==============================\n")
print("  Survived")
output_label_test = testing_data_encoded.iloc[: ,-1]
print(output_label_test)
# Out:
# Inputs Vectors (Feature Vectors) of Testing Data:
# =================================================
#
#     PClass  Gender  Sibling  Embarked  Predictions
# 80       2       1        2         2            0
# 81       2       0        3         2            1
# 82       2       1        3         2            0
# 83       0       1        0         2            1
# 84       1       1        3         2            0
# 85       2       0        0         1            1
# 86       1       1        3         2            0
# 87       0       0        0         2            1
# 88       2       1        3         2            0
# 89       1       0        3         2            1
# 90       1       1        3         2            0
# 91       1       0        3         2            1
# 92       2       1        3         0            0
# 93       0       1        0         2            1
# 94       0       1        0         2            0
# 95       2       1        0         0            1
# 96       2       1        0         1            0
# 97       2       1        0         2            1
# 98       1       1        0         2            0
# 99       2       1        0         2            1
#
#
# Outputs/Labels of Testing Data:
# ==============================
#
#   Survived
# 80    0
# 81    1
# 82    0
# 83    1
# 84    0
# 85    1
# 86    0
# 87    1
# 88    0
# 89    1
# 90    0
# 91    1
# 92    0
# 93    1
# 94    0
# 95    1
# 96    0
# 97    1
# 98    0
# 99    1
# Name: Predictions, dtype: int64

# %% [markdown]
# ## Step 7.2: Load the Saved Model

# %%
# Load the Saved Model

''' 
*------------------- LOAD_SAVED_MODEL --------------------------*
|         Function: load()                                      |
|               Purpose: Method to Load Previously Saved Model  |
|         Arguments:                                            |
|               Model: Trained Model                            |
|         Return:                                               |
|               File: Saved Model will be Loaded in Memory      |
*---------------------------------------------------------------*
'''

# Load the Saved Model

model = pickle.load(open('svc_trained_model.pkl', 'rb'))

# %% [markdown]
# ## Step 7.3: Evaluate the Machine Learning Model
# ### Step 7.3.1: Make Predictions with the Trained Models on Testing Data

# %%
# Evaluate the Machine Learning Model

''' 
*--------------------- EVALUATE_MACHINE_LEARNING_MODEL ----------------------*
|       Function: Predict()                                                  |
|             Purpose: Make a Prediction using Algorithm on Test Data        |
|       Arguments:                                                           |
|            Testing Data: Provide Test data to the Trained Model            |
|       Return:                                                              |
|            Predictions: Model return Predictions                           |
*----------------------------------------------------------------------------* 
'''

# Provide Test data to the Trained Model
print(input_vector_test)
model_predictions = model.predict(input_vector_test)
testing_data_encoded.copy(deep=True)
pd.options.mode.chained_assignment = None
testing_data_encoded["Predictions"] = model_predictions

# Save the Predictions into CSV File

testing_data_encoded.to_csv(r'model-predictions.csv', index = False, header = True)

model_predictions = testing_data_encoded 
print("\n\nPredictions Returned by svc_trained_model:")
print("==========================================\n")
print(model_predictions)
# Out:
#     PClass  Gender  Sibling  Embarked  Predictions
# 80       2       1        2         2            0
# 81       2       0        3         2            1
# 82       2       1        3         2            0
# 83       0       1        0         2            1
# 84       1       1        3         2            0
# 85       2       0        0         1            1
# 86       1       1        3         2            0
# 87       0       0        0         2            1
# 88       2       1        3         2            0
# 89       1       0        3         2            1
# 90       1       1        3         2            0
# 91       1       0        3         2            1
# 92       2       1        3         0            0
# 93       0       1        0         2            1
# 94       0       1        0         2            0
# 95       2       1        0         0            1
# 96       2       1        0         1            0
# 97       2       1        0         2            1
# 98       1       1        0         2            0
# 99       2       1        0         2            1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 16
#      14 # Provide Test data to the Trained Model
#      15 print(input_vector_test)
# ---> 16 model_predictions = model.predict(input_vector_test)
#      17 testing_data_encoded.copy(deep=True)
#      18 pd.options.mode.chained_assignment = None
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:822, in BaseSVC.predict(self, X)
#     820     y = np.argmax(self.decision_function(X), axis=1)
#     821 else:
# --> 822     y = super().predict(X)
#     823 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:436, in BaseLibSVM.predict(self, X)
#     420 def predict(self, X):
#     421     """Perform regression on samples in X.
#     422
#     423     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     434         The predicted values.
#     435     """
# --> 436     X = self._validate_for_predict(X)
#     437     predict = self._sparse_predict if self._sparse else self._dense_predict
#     438     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:614, in BaseLibSVM._validate_for_predict(self, X)
#     611 check_is_fitted(self)
#     613 if not callable(self.kernel):
# --> 614     X = validate_data(
#     615         self,
#     616         X,
#     617         accept_sparse="csr",
#     618         dtype=np.float64,
#     619         order="C",
#     620         accept_large_sparse=False,
#     621         reset=False,
#     622     )
#     624 if self._sparse and not sp.issparse(X):
#     625     X = sp.csr_matrix(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)
#    2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Predictions

# %% [markdown]
# ## Step 7.4: Calculate the Accuracy Score

# %%
# Calculate the Accuracy Score

''' 
/*------------------------ CALCULATE_ACCURACY_SCORE -------------------*
|          Function: accuracy_score()                                  |
|                Purpose: Evaluate the algorithm on Testing data       |
|          Arguments:                                                  |
|                Prediction: Predicted values                          |
|                Label: Actual values                                  |
|          Return:                                                     |
|                Accuracy: Accuracy Score                              |
*----------------------------------------------------------------------*
'''

# Calculate the Accuracy

model_accuracy_score = accuracy_score(model_predictions["Survived"],model_predictions["Predictions"])

print("\n\nAccuracy Score:")
print("===============\n")
print(round(model_accuracy_score,2))
# Out:
# Accuracy Score:
# ===============
#
# 1.0

# %% [markdown]
# # Step 8: Execute the Application Phase

# %% [markdown]
# ## Step 8.1: Take Input from User

# %%
# Take Input from User

''' 
*---------------- TAKE_USER_INPUT ----------------*
'''

pclass_input = input("\nPlease enter PClass here (First,Second,Third) : ").strip()
gender_input = input("\nPlease enter your Gender here (Male, Female) : ").strip()
sibling_input = input("\nPlease enter your Sibling here (Zero,One,Two,Three) : ").strip()
embarked_input = input("\nPlease enter Embarked here (Cherbourg,Southampton,Queenstown) : ").strip()
# Out:
# Please enter PClass here (First,Second,Third) :  Second
#
# Please enter your Gender here (Male, Female) :  Female
#
# Please enter your Sibling here (Zero,One,Two,Three) :  Three
#
# Please enter Embarked here (Cherbourg,Southampton,Queenstown) :  Queenstown

# %% [markdown]
# ## Step 8.2: Convert User Input into Feature Vector (Exactly Same as Feature Vectors of Sample Data)

# %%
# Convert User Input into Feature Vector

user_input = pd.DataFrame({ 'PClass': [pclass_input],'Gender': [gender_input],'Sibling': [sibling_input],'Embarked': [embarked_input]})

print("\n\nUser Input Feature Vector:")
print("==========================\n")
print(user_input)
# Out:
# User Input Feature Vector:
# ==========================
#
#    PClass  Gender Sibling    Embarked
# 0  Second  Female   Three  Queenstown

# %% [markdown]
# ## Step 8.3: Label Encoding of Feature Vector (Exactly Same as Label Encoded Feature Vectors of Sample Data)

# %%
''' 
*----------------- TRANSFORM_UNSEEN_INPUT_FEATURES ---------------*
|           Function: Transform()                                  |
|                 Purpose: Transform Input (Categorical) into      |
|                          Numerical Representation                |
|           Arguments:                                             |
|                 Attribute: Target values                         |
|           Return:                                                |
|                 Attribute: Numerical Representation              |
*------------------------------------------------------------------*   
'''

import pickle
import pandas as pd
import numpy as np

# ---------- LOAD ENCODERS ----------
with open("pclass_encoder.pkl", "rb") as f:
    pclass_label_encoder = pickle.load(f)
with open("gender_encoder.pkl", "rb") as f:
    gender_label_encoder = pickle.load(f)
with open("sibling_encoder.pkl", "rb") as f:
    sibling_label_encoder = pickle.load(f)
with open("embarked_encoder.pkl", "rb") as f:
    embarked_label_encoder = pickle.load(f)
with open("survived_encoder.pkl", "rb") as f:   # optional for inverse transform later
    survived_label_encoder = pickle.load(f)

ENCODERS = {
    "PClass": pclass_label_encoder,
    "Gender": gender_label_encoder,
    "Sibling": sibling_label_encoder,
    "Embarked": embarked_label_encoder
}

# ---------- (Optional) load your trained model ----------
# with open("model.pkl", "rb") as f:
#     model = pickle.load(f)
# If you don't have a saved model, set model = None
model = None

# ---------- Example user input (replace with real input) ----------
# user_input = pd.DataFrame([{
#     "PClass": "Second",
#     "Gender": "Female",
#     "Sibling": "One",
#     "Embarked": "Queenstown"
# }])
# or if you already have user_input DataFrame, keep it.

# ---------- Ensure target column isn't passed to model ----------
if "Survived" in user_input.columns:
    # drop target if present in user input
    user_input = user_input.drop(columns=["Survived"])

# ---------- Determine expected feature names ----------
if model is not None and hasattr(model, "feature_names_in_"):
    expected_features = list(model.feature_names_in_)
else:
    # If model not available or doesn't expose feature_names_in_, set expected list manually
    expected_features = ["PClass", "Gender", "Sibling", "Embarked"]  # adjust if your model used different names/order

# ---------- Align columns: drop extra, add missing (with NaN or default) ----------
# Drop any columns that are not expected
extra = [c for c in user_input.columns if c not in expected_features]
if extra:
    user_input = user_input.drop(columns=extra)

# Add any missing expected columns
missing = [c for c in expected_features if c not in user_input.columns]
if missing:
    # Option A: fill with NaN (or sensible default values)
    for c in missing:
        user_input[c] = np.nan
    # Option B (safer): raise an error so client must provide them
    # raise ValueError(f"Missing required features for prediction: {missing}")

# Reorder columns to match expected order
user_input = user_input[expected_features]

# ---------- Validate categorical values against encoders ----------
def validate_encoder_values(encoder, series, name):
    # Cast to string for comparison because encoder.classes_ are strings
    known = set(map(str, encoder.classes_))
    seen = set(map(str, series.dropna().astype(str)))
    unknown = list(seen - known)
    if unknown:
        raise ValueError(f"Unknown categories for {name}: {unknown}")

# Validate each categorical column that we will transform
for col, enc in ENCODERS.items():
    if col in user_input.columns:
        validate_encoder_values(enc, user_input[col], col)

# ---------- Transform categorical columns using loaded encoders ----------
unseen_data_features = user_input.copy()
# apply transforms only if column exists (prevents KeyError if missing)
if "PClass" in unseen_data_features.columns:
    unseen_data_features["PClass"] = pclass_label_encoder.transform(unseen_data_features["PClass"].astype(str))
if "Gender" in unseen_data_features.columns:
    unseen_data_features["Gender"] = gender_label_encoder.transform(unseen_data_features["Gender"].astype(str))
if "Sibling" in unseen_data_features.columns:
    unseen_data_features["Sibling"] = sibling_label_encoder.transform(unseen_data_features["Sibling"].astype(str))
if "Embarked" in unseen_data_features.columns:
    unseen_data_features["Embarked"] = embarked_label_encoder.transform(unseen_data_features["Embarked"].astype(str))

# If numeric columns exist they are left as-is.

print("\nUser Input Feature Vector:")
print(user_input)
print("\nUser Input Encoded Feature Vector:")
print(unseen_data_features)

# ---------- Now pass unseen_data_features to your model.predict(...) ----------
# features_array = unseen_data_features.to_numpy()
# pred_numeric = model.predict(features_array)[0]
# pred_label = survived_label_encoder.inverse_transform([pred_numeric])[0]
# Out:
# User Input Feature Vector:
#    PClass  Gender Sibling    Embarked
# 0  Second  Female   Three  Queenstown
#
# User Input Encoded Feature Vector:
#    PClass  Gender  Sibling  Embarked
# 0       1       0        1         1

# %% [markdown]
# ## Step 8.4: Load the Saved Model

# %%
# Load the Saved Model

''' 
*----------------------- LOAD_SAVED_MODEL --------------------------*
|         Function: load()                                          |
|             Purpose: Method to Load Previously Saved Model        |
|         Arguments:                                                |
|               Model: Trained Model                                |
|         Return:                                                   |
|               File: Saved Model will be Loaded in Memory          |
*-------------------------------------------------------------------*
'''

# Load the Saved Model

model = pickle.load(open('svc_trained_model.pkl', 'rb'))

# %% [markdown]
# ## Step 8.5: Model Prediction
# ### Step 8.5.1: Apply Model on the Label Encoded Feature Vector of unseen instance and return Prediction to the User

# %%
# Prediction of Unseen Instance

''' 
*----------------------------  MODEL_PREDICTION --------------------------*
|           Function: predict()                                           |
|                 Purpose: Use Trained Model to Predict the Output        |
|                          of Unseen Instances                            |
|           Arguments:                                                    |
|                 User Data: Label Encoded Feature Vector of              |
|                            Unseen Instances                             |
|           Return:                                                       |
|                 Survival: Survived or Not Survived                      |
*-------------------------------------------------------------------------*
'''

# Make a Prediction on Unseen Data

predicted_survival = model.predict(unseen_data_features)

if(predicted_survival == 1): 
    prediction = "SURVIVED"
if(predicted_survival == 0):
    prediction = "NOT SURVIVED"

# Add the Prediction in a Pretty Table

pretty_table = PrettyTable()
pretty_table.add_column("       ** Prediction **       ",[prediction])
print(pretty_table)
# Out:
# +--------------------------------+
# |        ** Prediction **        |
# +--------------------------------+
# |            SURVIVED            |
# +--------------------------------+

# %% [markdown]
# # Step 9: Execute the Feedback Phase
# ## A Two-Step Process
# ### Step 01: After some time, take Feedback from
#     o	Domain Experts and Users on deployed Titanic Passenger Survival Prediction System
# ### Step 02: Make a List of Possible Improvements based on Feedback received

# %% [markdown]
# # Step 10: Improve Model based on Feedback
# ### There is Always Room for Improvement
# ### Based on Feedback from Domain Experts and Users
#     o	Improve your Model

# %% [markdown]
# <br><br><br>
# <center> <h3 style="color:blue">==========================================================</h3> </center>
# <center> <h3 style="color:green">JAZAK ALLAH KHAIR</h3>
# <center> <h3 style="color:blue">==========================================================</h3> </center>
# <br><br><br>
